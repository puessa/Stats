# %%
# !pip install pycoingecko

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

import pandas as pd

# %%
cg.get_coin_history_by_id(id='bitcoin', vs_currency='usd', date='21-12-2019')
# Out:
# {'community_data': {'facebook_likes': None,
#   'reddit_accounts_active_48h': '4272.16666666667',
#   'reddit_average_comments_48h': 276.364,
#   'reddit_average_posts_48h': 7.455,
#   'reddit_subscribers': 1220735,
#   'twitter_followers': 68422},
#  'developer_data': {'closed_issues': 0,
#   'code_additions_deletions_4_weeks': {'additions': 2433, 'deletions': -1874},
#   'commit_count_4_weeks': 248,
#   'forks': 24815,
#   'pull_request_contributors': 629,
#   'pull_requests_merged': 7074,
#   'stars': 41621,
#   'subscribers': 3505,
#   'total_issues': 0},
#  'id': 'bitcoin',
#  'image': {'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579',
#   'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579'},
#  'localization': {'ar': 'بيتكوين',
#   'de': 'Bitcoin',
#   'en': 'Bitcoin',
#   'es': 'Bitcoin',
#   'fr': 'Bitcoin',
#   'hu': 'Bitcoin',
#   'id': 'Bitcoin',
#   'it': 'Bitcoin',
#   'ja': 'ビットコイン',
#   'ko': '비트코인',
# ...

# %%
data_btc = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days='360')

# %%
pd.DataFrame.from_dict(data_btc)
# Out:
#                                   prices  ...                        total_volumes
# 0     [1574035200000, 8508.499434051764]  ...  [1574035200000, 22808991914.563442]
# 1     [1574121600000, 8202.834446107912]  ...  [1574121600000, 25563738775.736923]
# 2     [1574208000000, 8138.831605359057]  ...   [1574208000000, 24993518393.55118]
# 3     [1574294400000, 8095.865638011639]  ...  [1574294400000, 23442272034.865948]
# 4     [1574380800000, 7632.494765498649]  ...  [1574380800000, 26390689050.100677]
# ..                                   ...  ...                                  ...
# 356   [1604793600000, 14818.45891122149]  ...   [1604793600000, 30369855794.73288]
# 357  [1604880000000, 15496.316149147417]  ...  [1604880000000, 24082570971.891495]
# 358  [1604966400000, 15335.342198178862]  ...   [1604966400000, 29501754042.78257]
# 359   [1605052800000, 15278.70965979927]  ...   [1605052800000, 21918753732.66584]
# ...
